# %% [markdown]
# <a href="https://colab.research.google.com/github/KentaroJay/git-boot-camp-20200610/blob/main/%E7%AC%AC%E4%B8%80%E5%9B%9E%E6%BC%94%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

# %%
# !git clone https://github.com/tarotez/pyml
# Out:
# Cloning into 'pyml'...
# remote: Enumerating objects: 372, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 372 (delta 2), reused 6 (delta 2), pack-reused 366
# Receiving objects: 100% (372/372), 17.11 MiB | 25.65 MiB/s, done.
# Resolving deltas: 100% (177/177), done.

# %%
cd pyml
# Out:
# /content/pyml

# %%
run linear_surface.py

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
for x in range(0,9):
  if x % 2 == 0:
    print(str(x) + "^2 = " + str(x*x))
# Out:
# 0^2 = 0
# 2^2 = 4
# 4^2 = 16
# 6^2 = 36
# 8^2 = 64

# %%
animals = ['dog', 'cat', 'mouse', 'gorilla']
summer = ('sun', 'beach', 'wave', 'sea', 'sky')

# %%
animals[0]
summer[1]
# Out:
# 'beach'

# %%
combined = [animals, summer]
combined
# Out:
# [['dog', 'cat', 'mouse', 'gorilla'], ('sun', 'beach', 'wave', 'sea', 'sky')]

# %%
str = "Hello World!"
print(str[4:11:2])
# Out:
# oWrd

# %%
animals.index('mouse')
# Out:
# 2

# %%
cd /content/
# Out:
# /content

# %%
f = open('（／BODY）の直前リタゲタグ.txt', 'r')
for line in f:
 print(line)
f.close()
# Out:
# <script async src="https://s.yimg.jp/images/listing/tool/cv/ytag.js"></script>
#
# <script>
#
# window.yjDataLayer = window.yjDataLayer || [];
#
# function ytag() { yjDataLayer.push(arguments); }
#
# ytag({
#
#   "type":"yjad_retargeting",
#
#   "config":{
#
#     "yahoo_retargeting_id": "42XQV6IK6L",
#
#     "yahoo_retargeting_label": ""
#
#     /*,
#
#     "yahoo_retargeting_page_type": "",
#
#     "yahoo_retargeting_items":[
#
#       {item_id: '', category_id: '', price: '', quantity: ''}
#
#     ]*/
#
#   }
#
# });
#
# </script>

# %%
import numpy as np

a = np.array([2, 3, 5, 7, 11, 13, 17, 19])
print(a)
b = a.reshape([4,2])
print(b)
# Out:
# [ 2  3  5  7 11 13 17 19]
# [[ 2  3]
#  [ 5  7]
#  [11 13]
#  [17 19]]

# %%
b.shape
# Out:
# (4, 2)

# %%
d = np.random.random((4,2))
print(d)
# Out:
# [[0.56105083 0.30424955]
#  [0.38797438 0.64926755]
#  [0.20017932 0.50644543]
#  [0.37251705 0.90147879]]

# %%
transposed = d.transpose([0,1])
print(transposed)
# Out:
# [[0.56105083 0.30424955]
#  [0.38797438 0.64926755]
#  [0.20017932 0.50644543]
#  [0.37251705 0.90147879]]
